# %% [markdown]
# <a href="https://colab.research.google.com/github/jayasurya21/Curneu-Assessment/blob/main/Heart_disease.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("/content/heart_failure_clinical_records_dataset.csv")

# %%
df.head()
# Out:
#     age  anaemia  creatinine_phosphokinase  ...  smoking  time  DEATH_EVENT
# 0  75.0        0                       582  ...        0     4            1
# 1  55.0        0                      7861  ...        0     6            1
# 2  65.0        0                       146  ...        1     7            1
# 3  50.0        1                       111  ...        0     7            1
# 4  65.0        1                       160  ...        0     8            1
#
# [5 rows x 13 columns]

# %%
df.shape
# Out:
# (299, 13)

# %%
df.describe
# Out:
# <bound method NDFrame.describe of       age  anaemia  creatinine_phosphokinase  ...  smoking  time  DEATH_EVENT
# 0    75.0        0                       582  ...        0     4            1
# 1    55.0        0                      7861  ...        0     6            1
# 2    65.0        0                       146  ...        1     7            1
# 3    50.0        1                       111  ...        0     7            1
# 4    65.0        1                       160  ...        0     8            1
# ..    ...      ...                       ...  ...      ...   ...          ...
# 294  62.0        0                        61  ...        1   270            0
# 295  55.0        0                      1820  ...        0   271            0
# 296  45.0        0                      2060  ...        0   278            0
# 297  45.0        0                      2413  ...        1   280            0
# 298  50.0        0                       196  ...        1   285            0
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 299 entries, 0 to 298
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   age                       299 non-null    float64
#  1   anaemia                   299 non-null    int64
#  2   creatinine_phosphokinase  299 non-null    int64
#  3   diabetes                  299 non-null    int64
#  4   ejection_fraction         299 non-null    int64
#  5   high_blood_pressure       299 non-null    int64
#  6   platelets                 299 non-null    float64
#  7   serum_creatinine          299 non-null    float64
#  8   serum_sodium              299 non-null    int64
#  9   sex                       299 non-null    int64
#  10  smoking                   299 non-null    int64
#  11  time                      299 non-null    int64
#  12  DEATH_EVENT               299 non-null    int64
# dtypes: float64(3), int64(10)
# memory usage: 30.5 KB

# %%
print("NO.of duplicate rows is",df.duplicated().sum())
# Out:
# NO.of duplicate rows is 0

# %%
df.hist(figsize=(16,16))
plt.title("Distribution")
plt.show()

# %%
import seaborn as sns

# %%
df['anaemia'].value_counts().plot.pie(autopct = '%1.1f%%', shadow= True, figsize = (6, 6)) 
plt.title("Aneamia")
plt.show()

# %%
df['diabetes'].value_counts().plot.pie(autopct = '%1.1f%%', shadow= True, figsize = (6, 6)) 
plt.title("diabetes")
plt.show()

# %%
df['DEATH_EVENT'].value_counts().plot.pie(autopct = '%1.1f%%', shadow= True, figsize = (6, 6)) 
plt.title("Death_Event")
plt.show()

# %%
sns.heatmap(df.corr(), annot=True)
plt.title("correlation heatmap")
plt.show()

# %%
df.corr()
# Out:
#                                age   anaemia  ...      time  DEATH_EVENT
# age                       1.000000  0.088006  ... -0.224068     0.253729
# anaemia                   0.088006  1.000000  ... -0.141414     0.066270
# creatinine_phosphokinase -0.081584 -0.190741  ... -0.009346     0.062728
# diabetes                 -0.101012 -0.012729  ...  0.033726    -0.001943
# ejection_fraction         0.060098  0.031557  ...  0.041729    -0.268603
# high_blood_pressure       0.093289  0.038182  ... -0.196439     0.079351
# platelets                -0.052354 -0.043786  ...  0.010514    -0.049139
# serum_creatinine          0.159187  0.052174  ... -0.149315     0.294278
# serum_sodium             -0.045966  0.041882  ...  0.087640    -0.195204
# sex                       0.065430 -0.094769  ... -0.015608    -0.004316
# smoking                   0.018668 -0.107290  ... -0.022839    -0.012623
# time                     -0.224068 -0.141414  ...  1.000000    -0.526964
# ...

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split

# %%
X = df.iloc[:,:-1].values
y = df.iloc[:,-1].values

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size = 0.33)

# %%
clf = RandomForestClassifier()

# %%
clf.fit(X_train,y_train)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(y_test,clf.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.81      0.91      0.86        68
#            1       0.73      0.52      0.60        31
#
#     accuracy                           0.79        99
#    macro avg       0.77      0.71      0.73        99
# weighted avg       0.78      0.79      0.78        99
